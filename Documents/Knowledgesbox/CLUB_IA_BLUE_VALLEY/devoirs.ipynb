# %%
print("====INSCRIPTION====")
prenom=str(input("Entrez votre prénom"))
nom=str(input("Entrez votre nom"))
age=int(input("Entrez votre âge"))
ville=str(input("Entrez votre ville"))
print(f"Bonjour {prenom} {nom} !")
print(f"tu as {age} ans et tu habites à {ville}")
# Out:
# ====INSCRIPTION====
# Entrez votre prénom vital
# Entrez votre nom AGNIDE
# Entrez votre âge 20
# Entrez votre ville Cotonou
# Bonjour vital AGNIDE !
# tu as 20 ans et tu habites à Cotonou

# %%
a=int(input("Entrez un nombre"))
b=int(input("Entrez un nombre"))
s=0
if a>b:
   a,b=b,a
    
for i in range(a+1,b):
            s+=i
print(f"La somme des entiers strictement compris entre {a} et {b} est :{s}")
# Out:
# Entrez un nombre 10
# Entrez un nombre 6
# La somme des entiers strictement compris entre 6 et 10 est :24

# %%
n=int(input("Entrez un nombre entier"))
m="*"
for i in range(1,n+1):
    print(m*i)
# Out:
# Entrez un nombre entier 5
# *
# **
# ***
# ****
# *****

# %%
n=int(input("Entrez un nombre entier"))
for i in range(1,n+1):
    for j in range(1,i+1):
        print(j,end="")
    print()
# Out:
# Entrez un nombre entier 5
# 1
# 12
# 123
# 1234
# 12345

# %%
import random
secret = random.randint(0, 100)
nbr=0
nbressai=0
while(nbressai<=10 and secret!=nbr):
    nbr=int(input("Devinez le nombre secret"))
    nbressai+=1
    if nbr<secret:
        print("Votre proposition", nbr ,"est trop petit")
    elif nbr>secret:
        print("Votre proposition", nbr ,"est trop grand")
    else:
        print("Votre proposition", nbr )
        print("Vous avez gagné après",nbressai,"essais")
if nbr != secret:
    print("Dommage, vous avez perdu. Le nombre était", secret)

# %%
1
# Out:
# 1
